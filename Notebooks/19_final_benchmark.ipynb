# %% [markdown]
# ### FINAL BENCHMARK

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path("..").resolve()

RESULTS_FOLDER = (
    PROJECT_ROOT
    / "Results"
    / "Final"
)

RESULTS_FOLDER.mkdir(
    parents=True,
    exist_ok=True
)

# %%
# =====================================================
# FINAL 60-QUERY BENCHMARK
# =====================================================

FINAL_QUERIES = [

    # =================================================
    # BRAND ONLY — 5
    # =================================================

    {
        "test_id": 1,
        "category": "Brand Only",
        "user_query": "Recommend a Samsung phone.",
        "expected_brand": "Samsung",
        "budget": None,
        "expected_features": "",
        "expected_outcome": "match"
    },

    {
        "test_id": 2,
        "category": "Brand Only",
        "user_query": "Recommend an Apple phone.",
        "expected_brand": "Apple",
        "budget": None,
        "expected_features": "",
        "expected_outcome": "match"
    },

    {
        "test_id": 3,
        "category": "Brand Only",
        "user_query": "Suggest a Motorola smartphone.",
        "expected_brand": "Motorola",
        "budget": None,
        "expected_features": "",
        "expected_outcome": "match"
    },

    {
        "test_id": 4,
        "category": "Brand Only",
        "user_query": "Recommend a Nokia phone.",
        "expected_brand": "Nokia",
        "budget": None,
        "expected_features": "",
        "expected_outcome": "match"
    },

    {
        "test_id": 5,
        "category": "Brand Only",
        "user_query": "Suggest a Google phone.",
        "expected_brand": "Google",
        "budget": None,
        "expected_features": "",
        "expected_outcome": "match"
    },

    # =================================================
    # BRAND + FEATURE — 8
    # =================================================

    {
        "test_id": 6,
        "category": "Brand + Feature",
        "user_query": "Recommend a Samsung phone with a good camera.",
        "expected_brand": "Samsung",
        "budget": None,
        "expected_features": "camera",
        "expected_outcome": "match"
    },

    {
        "test_id": 7,
        "category": "Brand + Feature",
        "user_query": "Recommend a Samsung phone with long battery life.",
        "expected_brand": "Samsung",
        "budget": None,
        "expected_features": "long battery life",
        "expected_outcome": "match"
    },

    {
        "test_id": 8,
        "category": "Brand + Feature",
        "user_query": "Recommend an Apple phone with a good camera.",
        "expected_brand": "Apple",
        "budget": None,
        "expected_features": "camera",
        "expected_outcome": "match"
    },

    {
        "test_id": 9,
        "category": "Brand + Feature",
        "user_query": "Suggest a Motorola phone with a good camera.",
        "expected_brand": "Motorola",
        "budget": None,
        "expected_features": "camera",
        "expected_outcome": "match"
    },

    {
        "test_id": 10,
        "category": "Brand + Feature",
        "user_query": "Recommend a Samsung phone with fast performance.",
        "expected_brand": "Samsung",
        "budget": None,
        "expected_features": "fast performance",
        "expected_outcome": "match"
    },

    {
        "test_id": 11,
        "category": "Brand + Feature",
        "user_query": "Recommend a Samsung phone for photography.",
        "expected_brand": "Samsung",
        "budget": None,
        "expected_features": "photography",
        "expected_outcome": "match"
    },

    {
        "test_id": 12,
        "category": "Brand + Feature",
        "user_query": "Suggest a Samsung smartphone for gaming.",
        "expected_brand": "Samsung",
        "budget": None,
        "expected_features": "gaming",
        "expected_outcome": "match"
    },

    {
        "test_id": 13,
        "category": "Brand + Feature",
        "user_query": "Recommend a Nokia phone with a good camera.",
        "expected_brand": "Nokia",
        "budget": None,
        "expected_features": "camera",
        "expected_outcome": "match"
    },

    # =================================================
    # BUDGET — 7
    # =================================================

    {
        "test_id": 14,
        "category": "Budget",
        "user_query": "Recommend a smartphone under 200.",
        "expected_brand": "",
        "budget": 200,
        "expected_features": "",
        "expected_outcome": "match"
    },

    {
        "test_id": 15,
        "category": "Budget",
        "user_query": "Recommend a smartphone under 250.",
        "expected_brand": "",
        "budget": 250,
        "expected_features": "",
        "expected_outcome": "match"
    },

    {
        "test_id": 16,
        "category": "Budget",
        "user_query": "Recommend a phone under 300.",
        "expected_brand": "",
        "budget": 300,
        "expected_features": "",
        "expected_outcome": "match"
    },

    {
        "test_id": 17,
        "category": "Budget",
        "user_query": "Suggest a smartphone under 400.",
        "expected_brand": "",
        "budget": 400,
        "expected_features": "",
        "expected_outcome": "match"
    },

    {
        "test_id": 18,
        "category": "Budget",
        "user_query": "Recommend a Samsung phone under 300.",
        "expected_brand": "Samsung",
        "budget": 300,
        "expected_features": "",
        "expected_outcome": "match"
    },

    {
        "test_id": 19,
        "category": "Budget",
        "user_query": "Recommend an Apple phone under 500.",
        "expected_brand": "Apple",
        "budget": 500,
        "expected_features": "",
        "expected_outcome": "match"
    },

    {
        "test_id": 20,
        "category": "Budget",
        "user_query": "Recommend a Motorola phone under 300.",
        "expected_brand": "Motorola",
        "budget": 300,
        "expected_features": "",
        "expected_outcome": "match"
    },

    # =================================================
    # FEATURE ONLY — 8
    # =================================================

    {
        "test_id": 21,
        "category": "Feature Only",
        "user_query": "Recommend a phone with a great camera.",
        "expected_brand": "",
        "budget": None,
        "expected_features": "camera",
        "expected_outcome": "match"
    },

    {
        "test_id": 22,
        "category": "Feature Only",
        "user_query": "Recommend a phone with long battery life.",
        "expected_brand": "",
        "budget": None,
        "expected_features": "long battery life",
        "expected_outcome": "match"
    },

    {
        "test_id": 23,
        "category": "Feature Only",
        "user_query": "Suggest a smartphone for gaming.",
        "expected_brand": "",
        "budget": None,
        "expected_features": "gaming",
        "expected_outcome": "match"
    },

    {
        "test_id": 24,
        "category": "Feature Only",
        "user_query": "I need a phone for photography.",
        "expected_brand": "",
        "budget": None,
        "expected_features": "photography",
        "expected_outcome": "match"
    },

    {
        "test_id": 25,
        "category": "Feature Only",
        "user_query": "Recommend a smartphone with fast performance.",
        "expected_brand": "",
        "budget": None,
        "expected_features": "fast performance",
        "expected_outcome": "match"
    },

    {
        "test_id": 26,
        "category": "Feature Only",
        "user_query": "Recommend a phone with fast charging.",
        "expected_brand": "",
        "budget": None,
        "expected_features": "fast charging",
        "expected_outcome": "match"
    },

    {
        "test_id": 27,
        "category": "Feature Only",
        "user_query": "Recommend a smartphone with good sound quality.",
        "expected_brand": "",
        "budget": None,
        "expected_features": "good sound quality",
        "expected_outcome": "match"
    },

    {
        "test_id": 28,
        "category": "Feature Only",
        "user_query": "Recommend a phone with large storage.",
        "expected_brand": "",
        "budget": None,
        "expected_features": "large storage",
        "expected_outcome": "match"
    },

    # =================================================
    # MULTIPLE FEATURES — 8
    # =================================================

    {
        "test_id": 29,
        "category": "Multiple Features",
        "user_query": "Recommend a phone with a good camera and long battery life.",
        "expected_brand": "",
        "budget": None,
        "expected_features": "camera|long battery life",
        "expected_outcome": "match"
    },

    {
        "test_id": 30,
        "category": "Multiple Features",
        "user_query": "Recommend a smartphone with a good camera and fast performance.",
        "expected_brand": "",
        "budget": None,
        "expected_features": "camera|fast performance",
        "expected_outcome": "match"
    },

    {
        "test_id": 31,
        "category": "Multiple Features",
        "user_query": "Recommend a phone with long battery life and fast charging.",
        "expected_brand": "",
        "budget": None,
        "expected_features": "long battery life|fast charging",
        "expected_outcome": "match"
    },

    {
        "test_id": 32,
        "category": "Multiple Features",
        "user_query": "Recommend a phone for gaming with long battery life.",
        "expected_brand": "",
        "budget": None,
        "expected_features": "gaming|long battery life",
        "expected_outcome": "match"
    },

    {
        "test_id": 33,
        "category": "Multiple Features",
        "user_query": "Recommend a phone for photography with large storage.",
        "expected_brand": "",
        "budget": None,
        "expected_features": "photography|large storage",
        "expected_outcome": "match"
    },

    {
        "test_id": 34,
        "category": "Multiple Features",
        "user_query": "Recommend a smartphone with a good camera, long battery life and fast performance.",
        "expected_brand": "",
        "budget": None,
        "expected_features": "camera|long battery life|fast performance",
        "expected_outcome": "match"
    },

    {
        "test_id": 35,
        "category": "Multiple Features",
        "user_query": "Recommend a phone with good sound quality and long battery life.",
        "expected_brand": "",
        "budget": None,
        "expected_features": "good sound quality|long battery life",
        "expected_outcome": "match"
    },

    {
        "test_id": 36,
        "category": "Multiple Features",
        "user_query": "Suggest a phone with fast charging and a good camera.",
        "expected_brand": "",
        "budget": None,
        "expected_features": "fast charging|camera",
        "expected_outcome": "match"
    },

    # =================================================
    # BRAND + BUDGET + FEATURES — 6
    # =================================================

    {
        "test_id": 37,
        "category": "Complex",
        "user_query": "Recommend a Samsung phone under 300 with a good camera.",
        "expected_brand": "Samsung",
        "budget": 300,
        "expected_features": "camera",
        "expected_outcome": "match"
    },

    {
        "test_id": 38,
        "category": "Complex",
        "user_query": "Recommend a Samsung phone under 400 with long battery life.",
        "expected_brand": "Samsung",
        "budget": 400,
        "expected_features": "long battery life",
        "expected_outcome": "match"
    },

    {
        "test_id": 39,
        "category": "Complex",
        "user_query": "Recommend an Apple phone under 500 with a good camera.",
        "expected_brand": "Apple",
        "budget": 500,
        "expected_features": "camera",
        "expected_outcome": "match"
    },

    {
        "test_id": 40,
        "category": "Complex",
        "user_query": "Recommend a Motorola phone under 300 with long battery life.",
        "expected_brand": "Motorola",
        "budget": 300,
        "expected_features": "long battery life",
        "expected_outcome": "match"
    },

    {
        "test_id": 41,
        "category": "Complex",
        "user_query": "Recommend a Samsung phone under 500 with a good camera and fast performance.",
        "expected_brand": "Samsung",
        "budget": 500,
        "expected_features": "camera|fast performance",
        "expected_outcome": "match"
    },

    {
        "test_id": 42,
        "category": "Complex",
        "user_query": "Recommend a Samsung phone under 500 with a good camera and long battery life.",
        "expected_brand": "Samsung",
        "budget": 500,
        "expected_features": "camera|long battery life",
        "expected_outcome": "match"
    },

    # =================================================
    # AMBIGUOUS — 5
    # =================================================

    {
        "test_id": 43,
        "category": "Ambiguous",
        "user_query": "Recommend the best Samsung phone.",
        "expected_brand": "Samsung",
        "budget": None,
        "expected_features": "",
        "expected_outcome": "match"
    },

    {
        "test_id": 44,
        "category": "Ambiguous",
        "user_query": "I need something good for photography.",
        "expected_brand": "",
        "budget": None,
        "expected_features": "photography",
        "expected_outcome": "match"
    },

    {
        "test_id": 45,
        "category": "Ambiguous",
        "user_query": "I need a phone that performs well.",
        "expected_brand": "",
        "budget": None,
        "expected_features": "fast performance",
        "expected_outcome": "match"
    },

    {
        "test_id": 46,
        "category": "Ambiguous",
        "user_query": "Suggest a good phone for travelling.",
        "expected_brand": "",
        "budget": None,
        "expected_features": "travel",
        "expected_outcome": "match"
    },

    {
        "test_id": 47,
        "category": "Ambiguous",
        "user_query": "I want a good all-round smartphone.",
        "expected_brand": "",
        "budget": None,
        "expected_features": "",
        "expected_outcome": "match"
    },

    # =================================================
    # UNSUPPORTED / NEGATIVE — 6
    # =================================================

    {
        "test_id": 48,
        "category": "Unsupported",
        "user_query": "Recommend an Apple phone with stylus support.",
        "expected_brand": "Apple",
        "budget": None,
        "expected_features": "stylus support",
        "expected_outcome": "no_match"
    },

    {
        "test_id": 49,
        "category": "Unsupported",
        "user_query": "Recommend a Samsung phone with a removable battery and an excellent camera.",
        "expected_brand": "Samsung",
        "budget": None,
        "expected_features": "removable battery|camera",
        "expected_outcome": "match"
    },

    {
        "test_id": 50,
        "category": "Unsupported",
        "user_query": "Recommend an Apple phone with a removable battery.",
        "expected_brand": "Apple",
        "budget": None,
        "expected_features": "removable battery",
        "expected_outcome": "no_match"
    },

    {
        "test_id": 51,
        "category": "Unsupported",
        "user_query": "Recommend a Samsung phone with stylus support and a removable battery.",
        "expected_brand": "Samsung",
        "budget": None,
        "expected_features": "stylus support|removable battery",
        "expected_outcome": "no_match"
    },

    {
        "test_id": 52,
        "category": "Unsupported",
        "user_query": "Recommend a Google phone with a removable battery.",
        "expected_brand": "Google",
        "budget": None,
        "expected_features": "removable battery",
        "expected_outcome": "no_match"
    },

    {
        "test_id": 53,
        "category": "Unsupported",
        "user_query": "Recommend an Apple phone with wireless charging and a removable battery.",
        "expected_brand": "Apple",
        "budget": None,
        "expected_features": "wireless charging|removable battery",
        "expected_outcome": "no_match"
    },

    # =================================================
    # IMPOSSIBLE / NO MATCH — 7
    # =================================================

    {
        "test_id": 54,
        "category": "No Match",
        "user_query": "Recommend a Nokia phone with an 8K camera and 1TB storage.",
        "expected_brand": "Nokia",
        "budget": None,
        "expected_features": "8k camera|1tb storage",
        "expected_outcome": "no_match"
    },

    {
        "test_id": 55,
        "category": "No Match",
        "user_query": "Recommend an Apple phone under 50.",
        "expected_brand": "Apple",
        "budget": 50,
        "expected_features": "",
        "expected_outcome": "no_match"
    },

    {
        "test_id": 56,
        "category": "No Match",
        "user_query": "Recommend a Samsung phone under 20 with a great camera.",
        "expected_brand": "Samsung",
        "budget": 20,
        "expected_features": "camera",
        "expected_outcome": "no_match"
    },

    {
        "test_id": 57,
        "category": "No Match",
        "user_query": "Recommend a Motorola phone with 1TB storage and an 8K camera.",
        "expected_brand": "Motorola",
        "budget": None,
        "expected_features": "1tb storage|8k camera",
        "expected_outcome": "no_match"
    },

    {
        "test_id": 58,
        "category": "No Match",
        "user_query": "Recommend a Google phone under 50 with long battery life.",
        "expected_brand": "Google",
        "budget": 50,
        "expected_features": "long battery life",
        "expected_outcome": "no_match"
    },

    {
        "test_id": 59,
        "category": "No Match",
        "user_query": "Recommend an Apple phone with an 8K camera and stylus support.",
        "expected_brand": "Apple",
        "budget": None,
        "expected_features": "8k camera|stylus support",
        "expected_outcome": "no_match"
    },

    {
        "test_id": 60,
        "category": "No Match",
        "user_query": "Recommend a Samsung phone under 10 with 1TB storage.",
        "expected_brand": "Samsung",
        "budget": 10,
        "expected_features": "1tb storage",
        "expected_outcome": "no_match"
    }
]


final_queries_df = pd.DataFrame(
    FINAL_QUERIES
)


print(
    "Final benchmark size:",
    len(final_queries_df)
)


display(
    final_queries_df
)
# Out:
# Final benchmark size: 60
#     test_id           category  \
# 0         1         Brand Only
# 1         2         Brand Only
# 2         3         Brand Only
# 3         4         Brand Only
# 4         5         Brand Only
# 5         6    Brand + Feature
# 6         7    Brand + Feature
# 7         8    Brand + Feature
# 8         9    Brand + Feature
# 9        10    Brand + Feature
# 10       11    Brand + Feature
# 11       12    Brand + Feature
# 12       13    Brand + Feature
# 13       14             Budget
# 14       15             Budget
# 15       16             Budget
# 16       17             Budget
# 17       18             Budget
# 18       19             Budget
# 19       20             Budget
# 20       21       Feature Only
# 21       22       Feature Only
# 22       23       Feature Only
# 23       24       Feature Only
# 24       25       Feature Only
# 25       26       Feature Only
# 26       27       Feature Only
# 27       28       Feature Only
# ...

# %%
benchmark_path = (
    RESULTS_FOLDER
    / "final_60_query_benchmark.csv"
)


final_queries_df.to_csv(
    benchmark_path,
    index=False
)


print(
    "Saved:",
    benchmark_path
)
# Out:
# Saved: C:\Users\srush\Desktop\Multi agent coordination\Results\Final\final_60_query_benchmark.csv
