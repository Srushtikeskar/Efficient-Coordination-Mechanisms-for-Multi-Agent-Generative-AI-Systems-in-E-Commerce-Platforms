# %%
import pandas as pd

# %%
import pandas as pd
from Agents.retrieval_agent import ProductQuery

test_queries = [

    # ---------- Brand ----------
    ProductQuery(
        product_type="phone",
        brand="Apple"
    ),

    ProductQuery(
        product_type="phone",
        brand="Samsung"
    ),

    # ---------- Budget ----------
    ProductQuery(
        product_type="phone",
        budget=30000
    ),

    ProductQuery(
        product_type="phone",
        budget=50000
    ),

    # ---------- Features ----------
    ProductQuery(
        product_type="phone",
        features=["good camera"]
    ),

    ProductQuery(
        product_type="phone",
        features=["fast performance"]
    ),

    ProductQuery(
        product_type="phone",
        features=["good battery"]
    ),

    # ---------- Multiple Constraints ----------
    ProductQuery(
        product_type="phone",
        brand="Apple",
        budget=50000,
        features=[
            "good camera",
            "fast performance"
        ]
    ),

    ProductQuery(
        product_type="phone",
        brand="Samsung",
        budget=30000,
        features=[
            "good battery"
        ]
    ),

    ProductQuery(
        product_type="phone",
        brand="Google",
        budget=60000,
        features=[
            "AI camera"
        ]
    ),

    # ---------- Edge Cases ----------
    ProductQuery(
        product_type="phone"
    ),

    ProductQuery(
        product_type="phone",
        features=[]
    ),

    ProductQuery(
        product_type="phone",
        brand=None,
        budget=None
    )
]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 from Agents.retrieval_agent import ProductQuery
#       4 test_queries = [
#       5
#       6     # ---------- Brand ----------
#    (...)
#      87     )
#      88 ]
#
# ModuleNotFoundError: No module named 'Agents'
